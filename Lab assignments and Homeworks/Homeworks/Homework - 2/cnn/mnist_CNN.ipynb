# %%
# %matplotlib inline
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import math

import matplotlib.pyplot as plt

# use GPU for computations if possible
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# temporarily patch this script until the MNIST data set download issue is resolved
# https://github.com/pytorch/vision/issues/1938
import urllib.request
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# %% [markdown]
# # Classification of hand-written digits
#
# We start by downloading and extracting the MNIST data set.

# %%
trainset = torchvision.datasets.MNIST(root='./data', train=True,
                                      download=True, transform=transforms.ToTensor())

testset = torchvision.datasets.MNIST(root='./data', train=False,
                                     download=True, transform=transforms.ToTensor())

# extract a complete PyTorch dataset
def extract(dataset):
    datasize = len(dataset)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=datasize, shuffle=False)
    return next(iter(dataloader))

# extract all test images and labels into PyTorch tensors
# the training data will be loaded in batches during training
test_X, test_Y = extract(testset)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 134884036.57it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 31228588.25it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 45678392.89it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 15289348.93it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Size of training dataset and test data set
print(f"Training data size: {len(trainset)}")
print(f"Test data size: {len(testset)}")
# Out:
# Training data size: 60000
# Test data size: 10000

# %% [markdown]
# ## The model
#
# The input data $X$ are grayscale images of $28\times 28$ pixels. The first dimension will be the number of data points that are provided to the network. The input data is flattened into a matrix with $28 \times 28 = 784$ columns using `X.view(-1, 784)`, where each column represents one pixel. We then apply first the linear transformation $X W + b$ and then the softmax function to obtain the class probabilities predicted by the model.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        U1 = 4
        U2 = 8
        U3 = 12
        U4 = 200
        U5 = 100

        self.W1 = nn.Parameter(0.1 * torch.randn(U1,1,5,5))
        self.W2 = nn.Parameter(0.1 * torch.randn(U2,U1,5,5))
        self.W3 = nn.Parameter(0.1 * torch.randn(U3,U2,4,4))
        self.W4 = nn.Parameter(0.1 * torch.randn(588,U4))
        self.W5 = nn.Parameter(0.1 * torch.randn(U4,U5))
        self.W6 = nn.Parameter(0.1 * torch.randn(U5,10))

        self.b1 = nn.Parameter(0.1 * torch.ones(U1))
        self.b2 = nn.Parameter(0.1 * torch.ones(U2))
        self.b3 = nn.Parameter(0.1 * torch.ones(U3))
        self.b4 = nn.Parameter(0.1 * torch.ones(U4))
        self.b5 = nn.Parameter(0.1 * torch.ones(U5))
        self.b6 = nn.Parameter(0.1 * torch.ones(10))

    def forward(self, X):
        Q1 = F.relu(F.conv2d(X, self.W1, bias=self.b1, stride=1, padding=2))
        Q2 = F.relu(F.conv2d(Q1, self.W2, bias=self.b2, stride=2, padding=2))
        Q3 = F.relu(F.conv2d(Q2, self.W3, bias=self.b3, stride=2, padding=1))
        Q3flat = Q3.view(-1,588)
        Q4 = F.relu(Q3flat.mm(self.W4)+self.b4)
        Q5 = F.relu(Q4.mm(self.W5)+self.b5)
        # apply the softmax function
        # G = F.softmax(Q5.mm(self.W6)+self.b6, dim=1)
        # return G

        z = Q5.mm(self.W6)+self.b6
        return z

# %% [markdown]
# ## The training
#
# We define the cross-entropy for the predicted probabilities $G$ (10-dimensional vectors) and the labels $Y$ (integers between 0 and 9).

# %%
def crossentropy(G, Y):
    # convert labels to onehot encoding
    Y_onehot = torch.eye(10, device=device)[Y]

    return -(Y_onehot * G.log()).sum(dim = 1).mean()

# %% [markdown]
# The next lines evaluate the accuracy of the predictions.

# %%
def accuracy(G, Y):
    return (G.argmax(dim=1) == Y).float().mean()

# %% [markdown]
# We are ready to train the network.

# %%
# initialize the test and training error statistics
test_accuracy = []
test_crossentropy = []
test_iter = []
train_accuracy = []
train_crossentropy = []
train_iter = []

# initialize the neural network and move it to the GPU if needed
net = Net()
net.to(device)

# define the optimization algorithm
# learningrate = 0.003
eta_min = 0.0001
eta_max = 0.003
# optimizer = optim.SGD(net.parameters(), lr=learningrate)
# optimizer = optim.Adam(net.parameters(), lr=learningrate)

# define the data loader for batches of the training data
batchsize = 100
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchsize, num_workers=2, shuffle=True)

# perform multiple training steps
# total_iterations = 2000 # total number of iterations
total_iterations = 6000
t = 0 # current iteration
done = False
while not done:
    learningrate = eta_min + (eta_max-eta_min) * math.exp(-t/2000)
    optimizer = optim.Adam(net.parameters(), lr=learningrate)
    for (batch_X, batch_Y) in trainloader:
        # move batch to the GPU if needed
        batch_X, batch_Y = batch_X.to(device), batch_Y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward pass
        batch_G = net(batch_X)
        # loss = crossentropy(batch_G, batch_Y)
        loss = F.cross_entropy(batch_G, batch_Y)

        # backpropagation
        loss.backward()

        # perform gradient descent step
        optimizer.step()

        # don't bother too much about the following lines!
        with torch.no_grad():
            # evaluate the performance on the training data at every 10th iteration
            if t % 10 == 0:
                train_crossentropy.append(loss.item())
                train_accuracy.append(accuracy(batch_G, batch_Y).item())
                train_iter.append(t)

            # evaluate the performance on the test data at every 100th iteration
            if t % 100 == 0:
                # move test data to the GPU if needed
                X, Y = test_X.to(device), test_Y.to(device)

                # compute predictions for the test data
                G = net(X)
                # test_crossentropy.append(crossentropy(G, Y).item())
                test_crossentropy.append(F.cross_entropy(G, Y).item())
                test_accuracy.append(accuracy(G, Y).item())
                test_iter.append(t)

                # print the iteration number and the accuracy of the predictions
                print(f"Step {t:5d}: train accuracy {100 * train_accuracy[-1]:6.2f}% " \
                      f"train cross-entropy {train_crossentropy[-1]:5.2f}  " \
                      f"test accuracy {100 * test_accuracy[-1]:6.2f}% " \
                      f"test cross-entropy {test_crossentropy[-1]:5.2f}")

        # stop the training after the specified number of iterations
        t += 1
        if t > total_iterations:
            done = True
            break
# Out:
# Step     0: train accuracy  11.00% train cross-entropy  2.43  test accuracy  10.32% test cross-entropy  2.32
# Step   100: train accuracy  94.00% train cross-entropy  0.39  test accuracy  93.19% test cross-entropy  0.24
# Step   200: train accuracy  97.00% train cross-entropy  0.10  test accuracy  95.70% test cross-entropy  0.14
# Step   300: train accuracy  95.00% train cross-entropy  0.21  test accuracy  95.89% test cross-entropy  0.13
# Step   400: train accuracy  98.00% train cross-entropy  0.06  test accuracy  97.60% test cross-entropy  0.08
# Step   500: train accuracy  96.00% train cross-entropy  0.08  test accuracy  97.76% test cross-entropy  0.07
# Step   600: train accuracy 100.00% train cross-entropy  0.01  test accuracy  97.66% test cross-entropy  0.07
# Step   700: train accuracy  99.00% train cross-entropy  0.02  test accuracy  97.87% test cross-entropy  0.07
# Step   800: train accuracy  99.00% train cross-entropy  0.03  test accuracy  97.87% test cross-entropy  0.06
# Step   900: train accuracy  98.00% train cross-entropy  0.04  test accuracy  98.11% test cross-entropy  0.06
# Step  1000: train accuracy  99.00% train cross-entropy  0.04  test accuracy  98.26% test cross-entropy  0.06
# Step  1100: train accuracy  95.00% train cross-entropy  0.09  test accuracy  98.44% test cross-entropy  0.05
# Step  1200: train accuracy  98.00% train cross-entropy  0.08  test accuracy  98.64% test cross-entropy  0.04
# Step  1300: train accuracy  99.00% train cross-entropy  0.03  test accuracy  98.61% test cross-entropy  0.05
# Step  1400: train accuracy  98.00% train cross-entropy  0.08  test accuracy  98.18% test cross-entropy  0.06
# Step  1500: train accuracy 100.00% train cross-entropy  0.02  test accuracy  98.75% test cross-entropy  0.04
# Step  1600: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.44% test cross-entropy  0.05
# Step  1700: train accuracy  99.00% train cross-entropy  0.03  test accuracy  98.69% test cross-entropy  0.04
# Step  1800: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.68% test cross-entropy  0.04
# Step  1900: train accuracy  99.00% train cross-entropy  0.04  test accuracy  98.88% test cross-entropy  0.04
# Step  2000: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.78% test cross-entropy  0.04
# Step  2100: train accuracy  97.00% train cross-entropy  0.05  test accuracy  98.88% test cross-entropy  0.04
# Step  2200: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.81% test cross-entropy  0.04
# Step  2300: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.76% test cross-entropy  0.04
# Step  2400: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.85% test cross-entropy  0.05
# Step  2500: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.87% test cross-entropy  0.04
# Step  2600: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.94% test cross-entropy  0.04
# Step  2700: train accuracy  99.00% train cross-entropy  0.01  test accuracy  98.83% test cross-entropy  0.04
# Step  2800: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.96% test cross-entropy  0.04
# Step  2900: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.88% test cross-entropy  0.04
# Step  3000: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.89% test cross-entropy  0.04
# Step  3100: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.92% test cross-entropy  0.04
# Step  3200: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.91% test cross-entropy  0.04
# Step  3300: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.01% test cross-entropy  0.04
# Step  3400: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.92% test cross-entropy  0.04
# Step  3500: train accuracy  99.00% train cross-entropy  0.04  test accuracy  98.98% test cross-entropy  0.04
# Step  3600: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.04% test cross-entropy  0.04
# Step  3700: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.98% test cross-entropy  0.04
# Step  3800: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.95% test cross-entropy  0.04
# Step  3900: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.97% test cross-entropy  0.05
# Step  4000: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.92% test cross-entropy  0.05
# Step  4100: train accuracy  99.00% train cross-entropy  0.01  test accuracy  98.97% test cross-entropy  0.05
# Step  4200: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.85% test cross-entropy  0.05
# Step  4300: train accuracy  99.00% train cross-entropy  0.01  test accuracy  98.90% test cross-entropy  0.05
# Step  4400: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.06% test cross-entropy  0.05
# Step  4500: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.06% test cross-entropy  0.05
# Step  4600: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.95% test cross-entropy  0.04
# Step  4700: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.04% test cross-entropy  0.04
# Step  4800: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.99% test cross-entropy  0.04
# Step  4900: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.01% test cross-entropy  0.05
# Step  5000: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.08% test cross-entropy  0.05
# Step  5100: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.95% test cross-entropy  0.06
# Step  5200: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.02% test cross-entropy  0.05
# Step  5300: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.02% test cross-entropy  0.05
# Step  5400: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.97% test cross-entropy  0.05
# Step  5500: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.01% test cross-entropy  0.05
# Step  5600: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.00% test cross-entropy  0.05
# Step  5700: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.01% test cross-entropy  0.05
# Step  5800: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.00% test cross-entropy  0.06
# Step  5900: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.03% test cross-entropy  0.06
# Step  6000: train accuracy 100.00% train cross-entropy  0.00  test accuracy  99.02% test cross-entropy  0.05

# %% [markdown]
# ## The evaluation
#
# The remaining code produces the plots needed to evaluate the training and predictions.

# %%
# plot the cross-entropy
plt.plot(train_iter, train_crossentropy, 'b-', label='Training data (mini-batch)')
plt.plot(test_iter, test_crossentropy, 'r-', label='Test data')
plt.xlabel('Iteration')
plt.ylabel('Cross-entropy')
plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the accuracy
plt.plot(train_iter, train_accuracy, 'b-', label='Training data (mini-batch)')
plt.plot(test_iter, test_accuracy, 'r-', label='Test data')
plt.xlabel('Iteration')
plt.ylabel('Prediction accuracy')
plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Prediction accuracy')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
# evaluate the network on 100 random test images
with torch.no_grad():
    # obtain 100 random samples from the test data set
    random_X, random_Y = next(iter(torch.utils.data.DataLoader(testset, batch_size=100, shuffle=True)))

    # move data to the GPU if needed
    random_X, random_Y = random_X.to(device), random_Y.to(device)

    # compute the predictions for the sampled inputs
    random_G = net(random_X)
    random_Yhat = random_G.argmax(dim=1)

    # sort the predictions with the incorrect ones first
    indices_incorrect_first = (random_Yhat == random_Y).float().argsort()

# plot the images
num_rows = 10
num_cols = 10
num_images = num_rows * num_cols
plt.figure(figsize=(num_cols, num_rows))

for i, index in enumerate(indices_incorrect_first, 1):
    plt.subplot(num_rows, num_cols, i)
    plt.xticks([])
    plt.yticks([])

    # plot the image
    plt.imshow(random_X[index, :, :].view(28, 28).cpu().numpy(), cmap=plt.cm.binary)

    # add the prediction as annotation (incorrect predictions in red, correct ones in blue)
    color = 'blue' if random_Yhat[index] == random_Y[index] else 'red'
    plt.text(0, 25, random_Yhat[index].item(), fontsize=25, color=color)

plt.show()
