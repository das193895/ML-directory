# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
df_train.shape
# Out:
# (550068, 12)

# %%
df_train.size
# Out:
# 6600816

# %%
columns = df_train.columns
columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df_test = pd.read_csv("test.csv")
df_test.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
# 5  1000013  P00350442      M  46-50           1             C
# 6  1000013  P00155442      M  46-50           1             C
# 7  1000013   P0094542      M  46-50           1             C
# 8  1000015  P00161842      M  26-35           7             A
# 9  1000022  P00067942      M  18-25          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# ...

# %%
df_test.shape
# Out:
# (233599, 11)

# %%
df_test.size
# Out:
# 2569589

# %%
df_test.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
# "purchase" column is not there in the test data set and there are more rows in train.csv than test.csv

# %%
# create a new data frame with train and test 
df = df_train.append(df_test)
df.head(10)
# Out:
# C:\Users\91797\AppData\Local\Temp\ipykernel_19448\3378545357.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test)
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe().T
# Out:
#                        count          mean          std        min        25%  \
# User_ID             783667.0  1.003029e+06  1727.266668  1000001.0  1001519.0
# Occupation          783667.0  8.079300e+00     6.522206        0.0        2.0
# Marital_Status      783667.0  4.097774e-01     0.491793        0.0        0.0
# Product_Category_1  783667.0  5.366196e+00     3.878160        1.0        1.0
# Product_Category_2  537685.0  9.844506e+00     5.089093        2.0        5.0
# Product_Category_3  237858.0  1.266860e+01     4.125510        3.0        9.0
# Purchase            550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                           50%        75%        max
# User_ID             1003075.0  1004478.0  1006040.0
# Occupation                7.0       14.0       20.0
# Marital_Status            0.0        1.0        1.0
# Product_Category_1        5.0        8.0       20.0
# Product_Category_2        9.0       15.0       18.0
# ...

# %%
df.drop(["User_ID"],axis = 1,inplace = True)
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df["Gender"] = df["Gender"].map({"F":0,"M":1})  # converting the gender column
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
# Handling categorical features Age

df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
# pd.get_dummies(df["Age"])
df["Age"] = df["Age"].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
# 2nd technique

# # Import label encoder 
# from sklearn import preprocessing 
  
# # label_encoder object knows  
# # how to understand word labels. 
# label_encoder = preprocessing.LabelEncoder() 
  
# # Encode labels in column 'species'. 
# df['Age']= label_encoder.fit_transform(df['Age']) 
  
# df['Age'].unique()

# %%
df.head(15)
# Out:
#    Product_ID  Gender  Age  Occupation City_Category  \
# 0   P00069042       0    1          10             A
# 1   P00248942       0    1          10             A
# 2   P00087842       0    1          10             A
# 3   P00085442       0    1          10             A
# 4   P00285442       1    7          16             C
# 5   P00193542       1    3          15             A
# 6   P00184942       1    5           7             B
# 7   P00346142       1    5           7             B
# 8    P0097242       1    5           7             B
# 9   P00274942       1    3          20             A
# 10  P00251242       1    3          20             A
# 11  P00014542       1    3          20             A
# 12  P00031342       1    3          20             A
# 13  P00145042       1    3          20             A
# 14  P00231342       0    6           9             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["City_Category"] = df["City_Category"].map({'A':1,'B':2,'C':3})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              1
# 1  P00248942       0    1          10              1
# 2  P00087842       0    1          10              1
# 3  P00085442       0    1          10              1
# 4  P00285442       1    7          16              3
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
## Missing values 

df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df["Product_Category_2"].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
# we hav to replace missing values of  the_product_2 category with its mode because it is a discreate feature

# %%
df["Product_Category_2"].mode()[0]
# Out:
# 8.0

# %%
df["Product_Category_2"] = df["Product_Category_2"].fillna(df["Product_Category_2"].mode()[0])

# %%
df["Product_Category_2"].isnull().sum()  # now there are no missing values
# Out:
# 0

# %%
df["Product_Category_3"].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df["Product_Category_3"].mode()[0]
# Out:
# 16.0

# %%
df["Product_Category_3"] = df["Product_Category_3"].fillna(df["Product_Category_3"].mode()[0])

# %%
df["Product_Category_3"].isnull().sum()  # now there are no missing values
# Out:
# 0

# %%
## fixing the column "Stay_In_Current_City_Years"

df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Stay_In_Current_City_Years"] = df["Stay_In_Current_City_Years"].map({'0':0,'1':1,'2':2,'3':3,'4+':4})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              1
# 1  P00248942       0    1          10              1
# 2  P00087842       0    1          10              1
# 3  P00085442       0    1          10              1
# 4  P00285442       1    7          16              3
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  int64
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 71.7+ MB
